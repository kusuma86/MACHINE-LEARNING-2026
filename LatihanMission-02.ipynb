# %%
import pandas as pd

data = {
    "temperature_c": [
        30, 32, 31, 34, 35, 37, 39, 41, 43, 45,
        46, 48, 50, 52, 54, 56, 58, 60, 62, 65
    ],

    "current_a": [
        1.8, 1.9, 1.8, 2.0, 2.1, 2.2, 2.3, 2.5, 2.7, 2.8,
        3.0, 3.1, 3.3, 3.5, 3.7, 3.9, 4.1, 4.3, 4.5, 4.8
    ],

    "vibration_mm_s": [
        0.20, 0.25, 0.22, 0.30, 0.35,
        0.40, 0.48, 0.60, 0.72, 0.85,
        0.95, 1.10, 1.25, 1.40, 1.60,
        1.80, 2.00, 2.20, 2.40, 2.70
    ],

    "rpm": [
        2900, 2890, 2910, 2880, 2870,
        2850, 2830, 2800, 2770, 2740,
        2710, 2680, 2650, 2610, 2570,
        2530, 2490, 2450, 2410, 2360
    ],

    "condition": [
        "Normal", "Normal", "Normal", "Normal", "Normal",
        "Normal", "Normal",
        "Warning", "Warning", "Warning", "Warning",
        "Warning", "Warning", "Warning",
        "Fault", "Fault", "Fault", "Fault", "Fault", "Fault"
    ]
}

df = pd.DataFrame(data)

df
# Out:
#     temperature_c  current_a  vibration_mm_s   rpm condition
# 0              30        1.8            0.20  2900    Normal
# 1              32        1.9            0.25  2890    Normal
# 2              31        1.8            0.22  2910    Normal
# 3              34        2.0            0.30  2880    Normal
# 4              35        2.1            0.35  2870    Normal
# 5              37        2.2            0.40  2850    Normal
# 6              39        2.3            0.48  2830    Normal
# 7              41        2.5            0.60  2800   Warning
# 8              43        2.7            0.72  2770   Warning
# 9              45        2.8            0.85  2740   Warning
# 10             46        3.0            0.95  2710   Warning
# 11             48        3.1            1.10  2680   Warning
# 12             50        3.3            1.25  2650   Warning
# 13             52        3.5            1.40  2610   Warning
# ...

# %% [markdown]
# ## Pertanyaan
#
# | No. | Pertanyaan                                                                                                                                        |
# | --: | ------------------------------------------------------------------------------------------------------------------------------------------------- |
# |   1 | Tampilkan seluruh data dengan kondisi `Fault`.                                                                                                    |
# |   2 | Tampilkan data dengan temperatur lebih dari 50°C.                                                                                                 |
# |   3 | Berapa jumlah data dengan temperatur lebih dari 50°C?                                                                                             |
# |   4 | Tampilkan data dengan arus lebih besar dari 4 A.                                                                                                  |
# |   5 | Tampilkan data dengan kondisi `Warning` dan temperatur lebih dari 45°C.                                                                           |
# |   6 | Tampilkan data dengan temperatur lebih dari 50°C **dan** vibration lebih dari 1.5 mm/s.                                                           |
# |   7 | Tampilkan data dengan kondisi `Warning` **atau** `Fault`.                                                                                         |
# |   8 | Gunakan `query()` untuk mencari data dengan temperatur lebih dari 55°C.                                                                           |
# |   9 | Gunakan `query()` untuk mencari data dengan `current_a > 3.5` dan `rpm < 2600`.                                                                   |
# |  10 | Hitung jumlah data untuk masing-masing kategori `condition`.                                                                                      |
# |  11 | Hitung rata-rata seluruh feature numerik berdasarkan `condition`.                                                                                 |
# |  12 | Hitung rata-rata temperatur untuk setiap `condition`.                                                                                             |
# |  13 | Cari temperatur maksimum untuk setiap `condition`.                                                                                                |
# |  14 | Cari vibration minimum dan maksimum untuk masing-masing `condition`.                                                                              |
# |  15 | Untuk setiap `condition`, tampilkan jumlah data, rata-rata temperatur, minimum temperatur, dan maksimum temperatur.                               |
# |  16 | Kondisi apa yang mempunyai rata-rata RPM paling rendah?                                                                                           |
# |  17 | Cari lima data dengan temperatur tertinggi.                                                                                                       |
# |  18 | Cari tiga data dengan vibration terendah.                                                                                                        |
# |  19 | Hitung correlation antar-feature numerik. Feature apa yang mempunyai hubungan positif kuat dengan temperatur?                                     |
# |  20 | Berdasarkan hasil eksplorasi, jelaskan perubahan temperature, current, vibration, dan RPM ketika kondisi berubah dari `Normal → Warning → Fault`. |

# %% [markdown]
# # Jawab:
